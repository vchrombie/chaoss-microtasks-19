# %% [markdown]
# # Microtask-6
#
# > Perform any other analysis you may find interesting, based on the Perceval data you collected.

# %%
import json
import csv
import regex
import requests

import pandas as pd
import matplotlib.pyplot as plt

from datetime import datetime
from collections import defaultdict

from prettytable import from_csv
from pprint import pprint

# %%
class Repository_Summary:
    
    def __init__(self, path):
        """
        """
        self.repodata = defaultdict(list)
        self.tempdf = pd.DataFrame()
        self.pr_count={'open':0, 'rejected':0, 'merged':0}
        
        self.df = {
            # commit has the column >> hash, author, date
            'commit':pd.DataFrame(columns=['hash', 'author', 'author_date',
                                           'commit', 'created_date', 'files_no']),
            # issue has the column >> hash, author, date
            'issue':pd.DataFrame(columns=['hash', 'author', 'created_date',
                                         'updated_date', 'comments', 'state']),
            # pr has the column >> hash, author, date
            'pull_request':pd.DataFrame(columns=['hash', 'author', 'created_date', 
                                        'closed_date', 'merged_date', 'comments','commits',
                                        'additions', 'deletions', 'changed_files', 'state'])
        }
        
        contents = defaultdict(list)

        # to filter out commit, issue, pr details from the data source and store them seperately in dict.
        with open('%s'%path) as datasrc:
            for line in datasrc:
                line = json.loads(line)
                if line['category'] == 'commit':    
                    content = self.summary_commit(line) 
                elif line['category'] == 'issue':    
                    content = self.summary_issue(line)
                elif line['category'] == 'pull_request':    
                    content = self.summary_pr(line) 
                contents[line['category']].append(content)
        for item in contents:
            self.df[item]=self.df[item].append(contents[item],sort=False)
            
            
    def summary_commit(self,commit):
        repo = commit['origin']
        data = commit['data']
        summary ={
                'repo': repo,
                'hash': data['commit'],
                'author': data['Author'],
                'author_date': datetime.strptime(data['AuthorDate'],
                                                          "%a %b %d %H:%M:%S %Y %z"),
                'commit': data['Commit'],
                'created_date': datetime.strptime(data['CommitDate'],
                                                          "%a %b %d %H:%M:%S %Y %z"),
                'files_no': len(data['files'])
        }
        actions = 0
        for file in data['files']:
            if 'action' in file:
                actions += 1
        summary['files_action'] = actions
        summary['merge'] = 'Merge' in data
        return summary
    
    def summary_issue(self,issue):
        repo = issue['origin']
        data = issue['data']
        summary ={
                'repo': repo,
                'hash': data['id'],
                'author': data['user']['login'],
                'created_date': datetime.strptime(data['created_at'],"%Y-%m-%dT%H:%M:%SZ"),
                'updated_date': datetime.strptime(data['updated_at'],"%Y-%m-%dT%H:%M:%SZ")
                                            if data['updated_at'] else None,
                'comments': data['comments'],
                'state': data['state']
        }
        return summary
    
    def summary_pr(self,pr):
        repo = pr['origin']
        data = pr['data']
        summary ={
                'repo': repo,
                'hash': data['id'],
                'author': data['user']['login'],
                'created_date': datetime.strptime(data['created_at'],"%Y-%m-%dT%H:%M:%SZ"),
                'closed_date': datetime.strptime(data['closed_at'],"%Y-%m-%dT%H:%M:%SZ")
                                            if data['closed_at'] else None,
                'merged_date': datetime.strptime(data['merged_at'],"%Y-%m-%dT%H:%M:%SZ")
                                            if data['merged_at'] else None,

                'comments': data['comments'],
                'commits': data['commits'],
                'additions': data['additions'],
                'deletions': data['deletions'],

                'changed_files': data['changed_files'],
                'state': data['state']
        }  
        return summary
    

    
    def print_pr_count(self):
        print("Open PR: ",pr_count['open'])
        print("Total Closed: ", pr_count['rejected']+pr_count['merged'])
        print("\tClosed but not Merged: ", pr_count['rejected'])
        print("\tClosed and Merged: ", pr_count['merged'])

    def plot_open_close(self):
        patches, texts = plt.pie([self.pr_count['open'], 
                                  self.pr_count['rejected']+self.pr_count['merged']],
                         colors=['yellowgreen', 'gold'], shadow=True,
                         startangle=90)
        plt.legend(patches, ['Open', 'Closed'], loc="best")
        plt.axis('equal')
        plt.tight_layout()
        plt.show()
        
    def plot_status(self):
        patches, texts = plt.pie([self.pr_count['open'], 
                                  self.pr_count['rejected']+self.pr_count['merged']],
                                 colors=['yellowgreen', 'lightskyblue', 'lightcoral'],
                                 shadow=True, startangle=90)
        plt.legend(patches, ['Open', 'Closed but not Merged', 'Closed and Merged'], loc="best")
        plt.axis('equal')
        plt.tight_layout()
        plt.show()  
    
    def replace_NaT_None(self):
        df2=self.df['pull_request']
        df2['closed_date']=df2['closed_date'].fillna('None')
        df2['merged_date']=df2['merged_date'].fillna('None')
        self.tempdf=df2
        
    def count_pr(self):
        df2=self.tempdf['pull_request']['pull_request']
        count=self.pr_count
        print(df2)

# %%
rdata=Repository_Summary("../data/elasticsearch-py.json")
rdata.replace_NaT_None()
rdata.count_pr()
rdata.print_pr_count()
rdata.plot_open_close()
rdata.plot_status()
# Out:
#           hash           author        created_date          closed_date  \
# 0      8604576           nkvoll 2013-09-25 19:01:36  2013-09-25 21:12:13
# 1      8755577           nkvoll 2013-10-01 21:51:40  2013-10-01 22:43:10
# 2      9429418        robhudson 2013-10-26 21:53:15  2013-10-26 21:56:36
# 3      9523758           obmarg 2013-10-30 13:02:24  2013-11-06 11:37:05
# 4      9882467           Murhaf 2013-11-12 14:22:16  2013-11-13 01:59:06
# 5     10034117    hariharan-uno 2013-11-17 20:47:39  2013-11-18 11:26:45
# 6     11023039        grasskode 2013-12-20 19:49:52  2013-12-21 14:09:57
# 7     11581886          igungor 2014-01-16 15:22:35  2014-01-16 15:32:11
# 8     11664633       speedplane 2014-01-20 06:54:49  2014-01-20 13:14:36
# 9     13096734        mkutsevol 2014-03-02 22:49:07  2014-03-03 12:39:03
# 10    14119214       sampaccoud 2014-03-28 16:52:09  2014-03-31 13:08:47
# 11    14219687           kosz85 2014-04-01 10:23:11  2014-04-01 23:27:01
# 12     9238143         rboulton 2013-10-20 12:54:15  2013-11-19 21:33:48
# 13    10136758         rboulton 2013-11-20 16:47:19  2013-11-22 13:32:22
# 14    15486614       ondrejsika 2014-05-05 10:17:01  2014-05-09 16:15:59
# 15    10747163       BrianHicks 2013-12-11 22:47:45  2013-12-16 15:35:36
# 16     8617268        robhudson 2013-09-26 04:37:19  2013-09-27 11:36:01
# 17    16148900            danni 2014-05-21 07:29:39  2014-05-22 22:18:46
# 18    17442616         frewsxcv 2014-06-21 20:19:16  2014-06-21 22:05:26
# 19    10167251           andrvb 2013-11-21 12:06:01  2014-01-30 10:57:59
# 20     8571519           nkvoll 2013-09-24 19:54:54  2013-09-24 21:08:57
# 21    15278979      pamelaBrain 2014-04-29 09:22:15  2014-05-05 06:27:30
# 8    closed  https://github.com/elastic/elasticsearch-py
# 9    closed  https://github.com/elastic/elasticsearch-py
# 10   closed  https://github.com/elastic/elasticsearch-py
# 11   closed  https://github.com/elastic/elasticsearch-py
# 12   closed  https://github.com/elastic/elasticsearch-py
# 13   closed  https://github.com/elastic/elasticsearch-py
# 14   closed  https://github.com/elastic/elasticsearch-py
# 15   closed  https://github.com/elastic/elasticsearch-py
# 16   closed  https://github.com/elastic/elasticsearch-py
# 17   closed  https://github.com/elastic/elasticsearch-py
# 18   closed  https://github.com/elastic/elasticsearch-py
# 19   closed  https://github.com/elastic/elasticsearch-py
# 20   closed  https://github.com/elastic/elasticsearch-py
# 21   closed  https://github.com/elastic/elasticsearch-py
# 22   closed  https://github.com/elastic/elasticsearch-py
# 23   closed  https://github.com/elastic/elasticsearch-py
# 24   closed  https://github.com/elastic/elasticsearch-py
# 25   closed  https://github.com/elastic/elasticsearch-py
# 26   closed  https://github.com/elastic/elasticsearch-py
# 27   closed  https://github.com/elastic/elasticsearch-py
# 28   closed  https://github.com/elastic/elasticsearch-py
# 29   closed  https://github.com/elastic/elasticsearch-py
# ..      ...                                          ...
# 260  closed  https://github.com/elastic/elasticsearch-py
# 261  closed  https://github.com/elastic/elasticsearch-py
# 262  closed  https://github.com/elastic/elasticsearch-py
# 263  closed  https://github.com/elastic/elasticsearch-py
# 264  closed  https://github.com/elastic/elasticsearch-py
# 265  closed  https://github.com/elastic/elasticsearch-py
# 266  closed  https://github.com/elastic/elasticsearch-py
# 267  closed  https://github.com/elastic/elasticsearch-py
# 268  closed  https://github.com/elastic/elasticsearch-py
# 269  closed  https://github.com/elastic/elasticsearch-py
# 270  closed  https://github.com/elastic/elasticsearch-py
# 271  closed  https://github.com/elastic/elasticsearch-py
# 272  closed  https://github.com/elastic/elasticsearch-py
# 273  closed  https://github.com/elastic/elasticsearch-py
# 274  closed  https://github.com/elastic/elasticsearch-py
# 275  closed  https://github.com/elastic/elasticsearch-py
# 276  closed  https://github.com/elastic/elasticsearch-py
# 277    open  https://github.com/elastic/elasticsearch-py
# 278  closed  https://github.com/elastic/elasticsearch-py
# 279  closed  https://github.com/elastic/elasticsearch-py
# 280  closed  https://github.com/elastic/elasticsearch-py
# 281  closed  https://github.com/elastic/elasticsearch-py
# 282  closed  https://github.com/elastic/elasticsearch-py
# 283    open  https://github.com/elastic/elasticsearch-py
# 284    open  https://github.com/elastic/elasticsearch-py
# 285  closed  https://github.com/elastic/elasticsearch-py
# 286    open  https://github.com/elastic/elasticsearch-py
# 287  closed  https://github.com/elastic/elasticsearch-py
# 288    open  https://github.com/elastic/elasticsearch-py
# 289    open  https://github.com/elastic/elasticsearch-py
#
# [290 rows x 12 columns]
# Open PR:  1
# Total Closed:  0
# 	Closed but not Merged:  0
# 	Closed and Merged:  0

# %%
rdata=Repository_Summary("../data/elasticsearch-py.json")
rdata.count_pr()
rdata.print_pr_count()
rdata.plot_open_close()
rdata.plot_status()
# Out:
# Open PR:  8
# Total Closed:  282
# 	Closed but not Merged:  151
# 	Closed and Merged:  131
